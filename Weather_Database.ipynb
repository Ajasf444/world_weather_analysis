# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import os
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
lat = np.random.uniform(-90, 90, size = 2000)
lng = np.random.uniform(-180, 180, size = 2000)
lat_lng = zip(lat, lng)
coordinates = list(lat_lng)

cities = []
for lat, lng in coordinates:
    city = citipy.nearest_city(lat, lng).city_name    
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for ii, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (ii % 50 == 0 and ii >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city.replace(' ', '+')
    
    # Log the URL, recond, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | guhagar
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | oksfjord
# Processing Record 9 of Set 1 | halifax
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 1 | mangrol
# Processing Record 13 of Set 1 | palmer
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | new bedford
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | tautira
# Processing Record 21 of Set 1 | lavrentiya
# Processing Record 22 of Set 1 | bud
# Processing Record 23 of Set 1 | camopi
# Processing Record 24 of Set 1 | avera
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | zelenoborsk
# Processing Record 29 of Set 1 | bubaque
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | saldanha
# Processing Record 32 of Set 1 | toba
# Processing Record 33 of Set 1 | staryy nadym
# Processing Record 34 of Set 1 | zhengjiatun
# Processing Record 35 of Set 1 | luau
# Processing Record 36 of Set 1 | olafsvik
# Processing Record 37 of Set 1 | mathathane
# Processing Record 38 of Set 1 | anloga
# Processing Record 39 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | aksha
# Processing Record 42 of Set 1 | banda aceh
# Processing Record 43 of Set 1 | vila do maio
# Processing Record 44 of Set 1 | kindersley
# Processing Record 45 of Set 1 | amapa
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | goderich
# Processing Record 49 of Set 1 | mayo
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | norfolk
# Processing Record 3 of Set 2 | alekseyevka
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | clyde river
# Processing Record 7 of Set 2 | mahon
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 2 | marawi
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | bayshore gardens
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | ahmadpur east
# Processing Record 17 of Set 2 | kuruman
# Processing Record 18 of Set 2 | khonsa
# Processing Record 19 of Set 2 | chapais
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 2 | fort nelson
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | noyabrsk
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | harrismith
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | vao
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 2 | arroyo
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | appiano
# City not found. Skipping...
# Processing Record 38 of Set 2 | candawaga
# City not found. Skipping...
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | praia
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | manokwari
# Processing Record 45 of Set 2 | nayoro
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 2 | homer
# Processing Record 49 of Set 2 | kutum
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | puerto el triunfo
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | dulag
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | kananga
# Processing Record 9 of Set 3 | dakar
# Processing Record 10 of Set 3 | virden
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | baherden
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | pali
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | bilibino
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | samarai
# Processing Record 21 of Set 3 | tual
# Processing Record 22 of Set 3 | oussouye
# Processing Record 23 of Set 3 | warmbad
# Processing Record 24 of Set 3 | santa vitoria do palmar
# Processing Record 25 of Set 3 | paramonga
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | krasnoselkup
# Processing Record 28 of Set 3 | mount gambier
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | kadi
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | nichinan
# Processing Record 33 of Set 3 | nardaran
# Processing Record 34 of Set 3 | santa cruz del norte
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | shahr-e kord
# Processing Record 37 of Set 3 | arman
# Processing Record 38 of Set 3 | torfyanoy
# Processing Record 39 of Set 3 | fairbanks
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | faanui
# Processing Record 42 of Set 3 | suez
# Processing Record 43 of Set 3 | sitka
# Processing Record 44 of Set 3 | terney
# Processing Record 45 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 3 | amagi
# Processing Record 47 of Set 3 | aasiaat
# Processing Record 48 of Set 3 | borascu
# Processing Record 49 of Set 3 | skibbereen
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | mareeba
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | pilar
# Processing Record 5 of Set 4 | summerville
# Processing Record 6 of Set 4 | aswan
# Processing Record 7 of Set 4 | totoral
# Processing Record 8 of Set 4 | sabang
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | ormara
# Processing Record 12 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 4 | marsh harbour
# Processing Record 14 of Set 4 | belem de sao francisco
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | keti bandar
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | axim
# Processing Record 20 of Set 4 | havelock
# Processing Record 21 of Set 4 | isaccea
# Processing Record 22 of Set 4 | hervey bay
# Processing Record 23 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 4 | ust-nera
# Processing Record 25 of Set 4 | tura
# Processing Record 26 of Set 4 | rocha
# Processing Record 27 of Set 4 | hobart
# Processing Record 28 of Set 4 | la asuncion
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | ugoofaaru
# Processing Record 33 of Set 4 | grafton
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | nuuk
# Processing Record 36 of Set 4 | dikson
# Processing Record 37 of Set 4 | amarpur
# Processing Record 38 of Set 4 | igarka
# Processing Record 39 of Set 4 | ambon
# Processing Record 40 of Set 4 | belmonte
# Processing Record 41 of Set 4 | baker city
# Processing Record 42 of Set 4 | bongor
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | constantine
# Processing Record 47 of Set 4 | rawson
# Processing Record 48 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | ajdabiya
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | tasiilaq
# Processing Record 5 of Set 5 | kumo
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | nhulunbuy
# Processing Record 8 of Set 5 | khovu-aksy
# Processing Record 9 of Set 5 | lac du bonnet
# Processing Record 10 of Set 5 | sakakah
# Processing Record 11 of Set 5 | port hawkesbury
# Processing Record 12 of Set 5 | abu dhabi
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | naro
# Processing Record 16 of Set 5 | road town
# Processing Record 17 of Set 5 | valley city
# Processing Record 18 of Set 5 | kenora
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | borovoy
# Processing Record 21 of Set 5 | meulaboh
# Processing Record 22 of Set 5 | hovd
# Processing Record 23 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 5 | venezuela
# Processing Record 25 of Set 5 | kilindoni
# Processing Record 26 of Set 5 | carndonagh
# Processing Record 27 of Set 5 | santiago del estero
# Processing Record 28 of Set 5 | tuatapere
# Processing Record 29 of Set 5 | veraval
# Processing Record 30 of Set 5 | cosala
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | bhayavadar
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | marsa matruh
# Processing Record 36 of Set 5 | mae sai
# Processing Record 37 of Set 5 | strezhevoy
# Processing Record 38 of Set 5 | praya
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | dongsheng
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | saint-louis
# Processing Record 45 of Set 5 | puerto baquerizo moreno
# Processing Record 46 of Set 5 | kuching
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | colchester
# Processing Record 50 of Set 5 | touros
# Processing Record 1 of Set 6 | ambilobe
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | nyurba
# Processing Record 4 of Set 6 | araguacu
# Processing Record 5 of Set 6 | pevek
# Processing Record 6 of Set 6 | labuhan
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | gigmoto
# Processing Record 9 of Set 6 | shakawe
# Processing Record 10 of Set 6 | okato
# Processing Record 11 of Set 6 | minab
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | sao joao do piaui
# Processing Record 14 of Set 6 | te anau
# Processing Record 15 of Set 6 | cartagena
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | bonavista
# Processing Record 18 of Set 6 | parabel
# Processing Record 19 of Set 6 | mastung
# Processing Record 20 of Set 6 | pozo colorado
# Processing Record 21 of Set 6 | betioky
# Processing Record 22 of Set 6 | petrolia
# Processing Record 23 of Set 6 | manyana
# Processing Record 24 of Set 6 | sioux falls
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | esqueda
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | shingu
# Processing Record 31 of Set 6 | ifanadiana
# Processing Record 32 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 6 | glace bay
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | hami
# Processing Record 36 of Set 6 | caxito
# Processing Record 37 of Set 6 | aqtobe
# Processing Record 38 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 6 | mpika
# Processing Record 40 of Set 6 | gotsu
# Processing Record 41 of Set 6 | lumphat
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | severo-yeniseyskiy
# Processing Record 45 of Set 6 | eureka
# Processing Record 46 of Set 6 | pangoa
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | mont-joli
# Processing Record 49 of Set 6 | show low
# Processing Record 50 of Set 6 | galle
# Processing Record 1 of Set 7 | zaplavnoye
# Processing Record 2 of Set 7 | sumbe
# Processing Record 3 of Set 7 | regina
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | hanzhong
# Processing Record 6 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 7 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 7 | mecca
# Processing Record 9 of Set 7 | nawa
# Processing Record 10 of Set 7 | concarneau
# Processing Record 11 of Set 7 | novo aripuana
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | west wendover
# Processing Record 14 of Set 7 | toamasina
# Processing Record 15 of Set 7 | soure
# Processing Record 16 of Set 7 | shakiso
# Processing Record 17 of Set 7 | khakhea
# Processing Record 18 of Set 7 | huilong
# Processing Record 19 of Set 7 | alofi
# Processing Record 20 of Set 7 | kamenka
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | nishihara
# Processing Record 23 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 7 | urdoma
# Processing Record 26 of Set 7 | draguignan
# Processing Record 27 of Set 7 | knyaze-volkonskoye
# Processing Record 28 of Set 7 | mogadishu
# Processing Record 29 of Set 7 | santa rosa
# Processing Record 30 of Set 7 | aloleng
# Processing Record 31 of Set 7 | uyemskiy
# Processing Record 32 of Set 7 | senneterre
# Processing Record 33 of Set 7 | les trois-ilets
# Processing Record 34 of Set 7 | belyy yar
# Processing Record 35 of Set 7 | amga
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | darien
# Processing Record 38 of Set 7 | ozernovskiy
# Processing Record 39 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 7 | coahuayana
# Processing Record 41 of Set 7 | vallenar
# Processing Record 42 of Set 7 | inhambane
# Processing Record 43 of Set 7 | antofagasta
# Processing Record 44 of Set 7 | shebunino
# Processing Record 45 of Set 7 | hualmay
# Processing Record 46 of Set 7 | gravdal
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | byron bay
# Processing Record 49 of Set 7 | half moon bay
# Processing Record 50 of Set 7 | klaksvik
# Processing Record 1 of Set 8 | kelo
# Processing Record 2 of Set 8 | novotroitsk
# Processing Record 3 of Set 8 | olenegorsk
# Processing Record 4 of Set 8 | naryan-mar
# Processing Record 5 of Set 8 | boende
# Processing Record 6 of Set 8 | uglegorsk
# Processing Record 7 of Set 8 | epe
# Processing Record 8 of Set 8 | sioux lookout
# Processing Record 9 of Set 8 | aykhal
# Processing Record 10 of Set 8 | saint-philippe
# Processing Record 11 of Set 8 | ponta do sol
# Processing Record 12 of Set 8 | tubmanburg
# Processing Record 13 of Set 8 | ahome
# Processing Record 14 of Set 8 | kiunga
# Processing Record 15 of Set 8 | bengkulu
# Processing Record 16 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 8 | nikolskoye
# Processing Record 18 of Set 8 | marrakesh
# Processing Record 19 of Set 8 | locri
# Processing Record 20 of Set 8 | tezu
# Processing Record 21 of Set 8 | tombouctou
# Processing Record 22 of Set 8 | parsons
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | atambua
# Processing Record 25 of Set 8 | menongue
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | agadir
# Processing Record 28 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 29 of Set 8 | hofn
# Processing Record 30 of Set 8 | tiarei
# Processing Record 31 of Set 8 | marilia
# Processing Record 32 of Set 8 | zavoronezhskoye
# Processing Record 33 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 8 | krotoszyn
# Processing Record 35 of Set 8 | rio gallegos
# Processing Record 36 of Set 8 | mana
# Processing Record 37 of Set 8 | ornskoldsvik
# Processing Record 38 of Set 8 | emerald
# Processing Record 39 of Set 8 | adrar
# Processing Record 40 of Set 8 | bathsheba
# Processing Record 41 of Set 8 | chicama
# Processing Record 42 of Set 8 | comodoro rivadavia
# Processing Record 43 of Set 8 | bethel
# Processing Record 44 of Set 8 | marienburg
# Processing Record 45 of Set 8 | robe
# Processing Record 46 of Set 8 | paamiut
# Processing Record 47 of Set 8 | nalut
# Processing Record 48 of Set 8 | baghdad
# Processing Record 49 of Set 8 | gelemso
# Processing Record 50 of Set 8 | murgab
# Processing Record 1 of Set 9 | burnie
# Processing Record 2 of Set 9 | konstantinovka
# Processing Record 3 of Set 9 | koungou
# Processing Record 4 of Set 9 | dongzhen
# Processing Record 5 of Set 9 | ayr
# Processing Record 6 of Set 9 | zhumadian
# Processing Record 7 of Set 9 | buta
# Processing Record 8 of Set 9 | bansgaon
# Processing Record 9 of Set 9 | bonthe
# Processing Record 10 of Set 9 | sokone
# Processing Record 11 of Set 9 | lichinga
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | charlottesville
# Processing Record 14 of Set 9 | zyryanka
# Processing Record 15 of Set 9 | pangkalanbuun
# Processing Record 16 of Set 9 | birin
# Processing Record 17 of Set 9 | esperance
# Processing Record 18 of Set 9 | zvishavane
# Processing Record 19 of Set 9 | san juan
# Processing Record 20 of Set 9 | bucerias
# Processing Record 21 of Set 9 | saint-augustin
# Processing Record 22 of Set 9 | shelburne
# Processing Record 23 of Set 9 | guadalupe y calvo
# Processing Record 24 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 9 | porto novo
# Processing Record 26 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 28 of Set 9 | abashiri
# Processing Record 29 of Set 9 | grand-lahou
# Processing Record 30 of Set 9 | waddan
# Processing Record 31 of Set 9 | sonamukhi
# Processing Record 32 of Set 9 | sitio novo do tocantins
# Processing Record 33 of Set 9 | mandali
# Processing Record 34 of Set 9 | ketchikan
# Processing Record 35 of Set 9 | coos bay
# Processing Record 36 of Set 9 | iskateley
# Processing Record 37 of Set 9 | yaan
# Processing Record 38 of Set 9 | bara
# Processing Record 39 of Set 9 | altagracia de orituco
# Processing Record 40 of Set 9 | aksay
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | hearst
# Processing Record 43 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 9 | maniitsoq
# Processing Record 45 of Set 9 | parit buntar
# Processing Record 46 of Set 9 | kez
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 9 | omboue
# Processing Record 50 of Set 9 | araouane
# Processing Record 1 of Set 10 | gamba
# Processing Record 2 of Set 10 | shkotovo-26
# City not found. Skipping...
# Processing Record 3 of Set 10 | dandong
# Processing Record 4 of Set 10 | bellary
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | mujiayingzi
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | dingle
# Processing Record 9 of Set 10 | robertson
# Processing Record 10 of Set 10 | ahuimanu
# Processing Record 11 of Set 10 | camargo
# Processing Record 12 of Set 10 | egvekinot
# Processing Record 13 of Set 10 | aklavik
# Processing Record 14 of Set 10 | beroroha
# Processing Record 15 of Set 10 | cap malheureux
# Processing Record 16 of Set 10 | buturlinovka
# Processing Record 17 of Set 10 | kesinga
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | caravelas
# Processing Record 20 of Set 10 | katete
# Processing Record 21 of Set 10 | emba
# Processing Record 22 of Set 10 | smithers
# Processing Record 23 of Set 10 | slave lake
# Processing Record 24 of Set 10 | chernenko
# Processing Record 25 of Set 10 | bibiani
# Processing Record 26 of Set 10 | gazojak
# Processing Record 27 of Set 10 | wilmington
# Processing Record 28 of Set 10 | mbacke
# City not found. Skipping...
# Processing Record 29 of Set 10 | pisco
# Processing Record 30 of Set 10 | roald
# Processing Record 31 of Set 10 | bac lieu
# Processing Record 32 of Set 10 | port-gentil
# Processing Record 33 of Set 10 | salinas
# Processing Record 34 of Set 10 | katherine
# Processing Record 35 of Set 10 | concordia
# Processing Record 36 of Set 10 | cacoal
# Processing Record 37 of Set 10 | kwinana
# Processing Record 38 of Set 10 | nizhniy baskunchak
# Processing Record 39 of Set 10 | kavaratti
# Processing Record 40 of Set 10 | castlegar
# Processing Record 41 of Set 10 | itoman
# Processing Record 42 of Set 10 | awbari
# Processing Record 43 of Set 10 | plettenberg bay
# Processing Record 44 of Set 10 | kemijarvi
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | haines junction
# Processing Record 47 of Set 10 | saint anthony
# Processing Record 48 of Set 10 | foumban
# Processing Record 49 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | port hedland
# Processing Record 2 of Set 11 | komsomolskiy
# Processing Record 3 of Set 11 | roma
# Processing Record 4 of Set 11 | ndioum
# Processing Record 5 of Set 11 | susanville
# Processing Record 6 of Set 11 | manzhouli
# Processing Record 7 of Set 11 | la ronge
# Processing Record 8 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 11 | san carlos
# Processing Record 11 of Set 11 | yabelo
# Processing Record 12 of Set 11 | saraland
# Processing Record 13 of Set 11 | macedo de cavaleiros
# Processing Record 14 of Set 11 | troy
# Processing Record 15 of Set 11 | andra
# Processing Record 16 of Set 11 | coari
# Processing Record 17 of Set 11 | codrington
# Processing Record 18 of Set 11 | santa helena de goias
# Processing Record 19 of Set 11 | gualeguay
# Processing Record 20 of Set 11 | srednekolymsk
# Processing Record 21 of Set 11 | vila franca do campo
# Processing Record 22 of Set 11 | lodja
# Processing Record 23 of Set 11 | alihe
# Processing Record 24 of Set 11 | poya
# Processing Record 25 of Set 11 | nouadhibou
# Processing Record 26 of Set 11 | minggang
# Processing Record 27 of Set 11 | lompoc
# Processing Record 28 of Set 11 | leningradskiy
# Processing Record 29 of Set 11 | jiuquan
# Processing Record 30 of Set 11 | alyangula
# Processing Record 31 of Set 11 | mandalgovi
# Processing Record 32 of Set 11 | kodinsk
# Processing Record 33 of Set 11 | dimona
# Processing Record 34 of Set 11 | santa maria
# Processing Record 35 of Set 11 | kristiansund
# Processing Record 36 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 11 | kemin
# Processing Record 38 of Set 11 | maraa
# Processing Record 39 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 11 | fukue
# Processing Record 41 of Set 11 | pingdu
# Processing Record 42 of Set 11 | luanda
# Processing Record 43 of Set 11 | bhandara
# Processing Record 44 of Set 11 | flinders
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | punta alta
# Processing Record 47 of Set 11 | cruzeiro do oeste
# Processing Record 48 of Set 11 | hay river
# Processing Record 49 of Set 11 | bosaso
# Processing Record 50 of Set 11 | muros
# Processing Record 1 of Set 12 | milkovo
# Processing Record 2 of Set 12 | brookhaven
# Processing Record 3 of Set 12 | pangnirtung
# Processing Record 4 of Set 12 | katsuura
# Processing Record 5 of Set 12 | kosice
# Processing Record 6 of Set 12 | xining
# Processing Record 7 of Set 12 | orito
# Processing Record 8 of Set 12 | bikaner
# Processing Record 9 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 12 | la palma
# Processing Record 11 of Set 12 | cascais
# Processing Record 12 of Set 12 | ilulissat
# Processing Record 13 of Set 12 | santa isabel do rio negro
# Processing Record 14 of Set 12 | surt
# Processing Record 15 of Set 12 | broome
# Processing Record 16 of Set 12 | sao jose da coroa grande
# Processing Record 17 of Set 12 | pecos
# Processing Record 18 of Set 12 | mackay
# Processing Record 19 of Set 12 | merritt island
# Processing Record 20 of Set 12 | kigoma
# Processing Record 21 of Set 12 | lagoa
# Processing Record 22 of Set 12 | descalvado
# Processing Record 23 of Set 12 | sanmenxia
# Processing Record 24 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 12 | price
# Processing Record 26 of Set 12 | nome
# Processing Record 27 of Set 12 | kot kapura
# Processing Record 28 of Set 12 | saint-leu
# Processing Record 29 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 12 | vynohradivka
# Processing Record 31 of Set 12 | santa cruz
# Processing Record 32 of Set 12 | atsiki
# City not found. Skipping...
# Processing Record 33 of Set 12 | bairiki
# Processing Record 34 of Set 12 | killybegs
# Processing Record 35 of Set 12 | noumea
# Processing Record 36 of Set 12 | mukono
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | taoudenni
# Processing Record 39 of Set 12 | binzhou
# Processing Record 40 of Set 12 | surman
# Processing Record 41 of Set 12 | geraldton
# Processing Record 42 of Set 12 | thinadhoo
# Processing Record 43 of Set 12 | japura
# Processing Record 44 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 12 | saint-pierre
# Processing Record 46 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 47 of Set 12 | tallahassee
# Processing Record 48 of Set 12 | puerto del rosario
# Processing Record 49 of Set 12 | kholodnyy
# Processing Record 50 of Set 12 | general pico
# Processing Record 1 of Set 13 | dillon
# Processing Record 2 of Set 13 | guerrero negro
# Processing Record 3 of Set 13 | sao luiz gonzaga
# Processing Record 4 of Set 13 | khasan
# Processing Record 5 of Set 13 | wyndham
# Processing Record 6 of Set 13 | luanshya
# Processing Record 7 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 8 of Set 13 | kungurtug
# Processing Record 9 of Set 13 | dangriga
# Processing Record 10 of Set 13 | mawlaik
# Processing Record 11 of Set 13 | yarmouth
# Processing Record 12 of Set 13 | frontera
# Processing Record 13 of Set 13 | novi ligure
# Processing Record 14 of Set 13 | savonlinna
# Processing Record 15 of Set 13 | gatton
# Processing Record 16 of Set 13 | port blair
# Processing Record 17 of Set 13 | athens
# Processing Record 18 of Set 13 | chelyabinsk-40
# City not found. Skipping...
# Processing Record 19 of Set 13 | rovaniemi
# Processing Record 20 of Set 13 | eskisehir
# Processing Record 21 of Set 13 | bowen
# Processing Record 22 of Set 13 | san patricio
# Processing Record 23 of Set 13 | rio grande
# Processing Record 24 of Set 13 | kaiyuan
# Processing Record 25 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 26 of Set 13 | asau
# Processing Record 27 of Set 13 | guiratinga
# Processing Record 28 of Set 13 | namatanai
# Processing Record 29 of Set 13 | mocuba
# Processing Record 30 of Set 13 | oranjemund
# Processing Record 31 of Set 13 | ranipur
# Processing Record 32 of Set 13 | nantucket
# Processing Record 33 of Set 13 | purwodadi
# Processing Record 34 of Set 13 | alagoinhas
# Processing Record 35 of Set 13 | saint pete beach
# Processing Record 36 of Set 13 | honiara
# Processing Record 37 of Set 13 | cayenne
# Processing Record 38 of Set 13 | hauterive
# Processing Record 39 of Set 13 | upington
# Processing Record 40 of Set 13 | lazaro cardenas
# Processing Record 41 of Set 13 | novyy oskol
# Processing Record 42 of Set 13 | scarborough
# Processing Record 43 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 13 | bafra
# Processing Record 45 of Set 13 | roatan
# Processing Record 46 of Set 13 | victor harbor
# Processing Record 47 of Set 13 | bahce
# Processing Record 48 of Set 13 | pangai
# Processing Record 49 of Set 13 | predivinsk
# Processing Record 50 of Set 13 | ixtapa
# Processing Record 1 of Set 14 | george
# Processing Record 2 of Set 14 | malko tarnovo
# Processing Record 3 of Set 14 | karabuk
# Processing Record 4 of Set 14 | ciudad ojeda
# Processing Record 5 of Set 14 | taunggyi
# Processing Record 6 of Set 14 | glens falls
# Processing Record 7 of Set 14 | chillan
# Processing Record 8 of Set 14 | evensk
# Processing Record 9 of Set 14 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 10 of Set 14 | north platte
# Processing Record 11 of Set 14 | coruripe
# Processing Record 12 of Set 14 | karema
# Processing Record 13 of Set 14 | goldap
# Processing Record 14 of Set 14 | megion
# Processing Record 15 of Set 14 | walvis bay
# Processing Record 16 of Set 14 | pandan
# Processing Record 17 of Set 14 | florian
# Processing Record 18 of Set 14 | gobabis
# Processing Record 19 of Set 14 | koslan
# Processing Record 20 of Set 14 | voh
# Processing Record 21 of Set 14 | kuragino
# Processing Record 22 of Set 14 | jieshi
# Processing Record 23 of Set 14 | viedma
# Processing Record 24 of Set 14 | college
# Processing Record 25 of Set 14 | palauig
# Processing Record 26 of Set 14 | makiyivka
# Processing Record 27 of Set 14 | kracheh
# City not found. Skipping...
# Processing Record 28 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 14 | uruguaiana
# Processing Record 30 of Set 14 | smirnykh
# Processing Record 31 of Set 14 | wencheng
# Processing Record 32 of Set 14 | kampot
# Processing Record 33 of Set 14 | skjervoy
# Processing Record 34 of Set 14 | nakamura
# Processing Record 35 of Set 14 | dedougou
# Processing Record 36 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 14 | broken hill
# Processing Record 38 of Set 14 | awjilah
# Processing Record 39 of Set 14 | podgorica
# Processing Record 40 of Set 14 | moose factory
# Processing Record 41 of Set 14 | okhotsk
# Processing Record 42 of Set 14 | gudari
# Processing Record 43 of Set 14 | calabozo
# Processing Record 44 of Set 14 | biancavilla
# Processing Record 45 of Set 14 | mahajanga
# Processing Record 46 of Set 14 | mount isa
# Processing Record 47 of Set 14 | umm lajj
# Processing Record 48 of Set 14 | atasu
# Processing Record 49 of Set 14 | irituia
# Processing Record 50 of Set 14 | saint-francois
# Processing Record 1 of Set 15 | san jeronimo
# Processing Record 2 of Set 15 | asekeyevo
# Processing Record 3 of Set 15 | atherton
# Processing Record 4 of Set 15 | acarau
# Processing Record 5 of Set 15 | iqaluit
# Processing Record 6 of Set 15 | coihueco
# Processing Record 7 of Set 15 | alappuzha
# Processing Record 8 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 9 of Set 15 | grand-santi
# Processing Record 10 of Set 15 | almaznyy
# Processing Record 11 of Set 15 | kovacica
# Processing Record 12 of Set 15 | zhigansk
# Processing Record 13 of Set 15 | tainan
# Processing Record 14 of Set 15 | san jose
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | kalmunai
# Processing Record 17 of Set 15 | trinidad
# Processing Record 18 of Set 15 | wageningen
# Processing Record 19 of Set 15 | teahupoo
# Processing Record 20 of Set 15 | jega
# Processing Record 21 of Set 15 | utraula
# Processing Record 22 of Set 15 | khandyga
# Processing Record 23 of Set 15 | khon kaen
# Processing Record 24 of Set 15 | vestmanna
# Processing Record 25 of Set 15 | coolum beach
# Processing Record 26 of Set 15 | north bend
# Processing Record 27 of Set 15 | batagay-alyta
# Processing Record 28 of Set 15 | hoorn
# Processing Record 29 of Set 15 | pacific grove
# Processing Record 30 of Set 15 | madre de deus
# Processing Record 31 of Set 15 | ponta delgada
# Processing Record 32 of Set 15 | mbekenyera
# Processing Record 33 of Set 15 | bilma
# Processing Record 34 of Set 15 | eyl
# Processing Record 35 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 15 | vung tau
# Processing Record 37 of Set 15 | talara
# Processing Record 38 of Set 15 | ritchie
# Processing Record 39 of Set 15 | ngunguru
# Processing Record 40 of Set 15 | moosomin
# Processing Record 41 of Set 15 | navalmoral de la mata
# Processing Record 42 of Set 15 | gizo
# Processing Record 43 of Set 15 | mankono
# Processing Record 44 of Set 15 | bodden town
# Processing Record 45 of Set 15 | la libertad
# Processing Record 46 of Set 15 | milin
# Processing Record 47 of Set 15 | tromso
# Processing Record 48 of Set 15 | naigarhi
# Processing Record 49 of Set 15 | salinopolis
# Processing Record 50 of Set 15 | elko
# Processing Record 1 of Set 16 | satinka
# Processing Record 2 of Set 16 | imeni poliny osipenko
# Processing Record 3 of Set 16 | ilam
# Processing Record 4 of Set 16 | olinda
# Processing Record 5 of Set 16 | ahtopol
# Processing Record 6 of Set 16 | inuvik
# Processing Record 7 of Set 16 | hobyo
# Processing Record 8 of Set 16 | jasper
# Processing Record 9 of Set 16 | swift current
# Processing Record 10 of Set 16 | lindi
# Processing Record 11 of Set 16 | a
# City not found. Skipping...
# Processing Record 12 of Set 16 | hashtrud
# Processing Record 13 of Set 16 | juifang
# City not found. Skipping...
# Processing Record 14 of Set 16 | jiaojiang
# Processing Record 15 of Set 16 | port-cartier
# Processing Record 16 of Set 16 | belaya gora
# Processing Record 17 of Set 16 | imbituba
# Processing Record 18 of Set 16 | capaci
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.7826  147.0587     52.66        58          98
# 1      Guhagar      IN  17.4842   73.1929     73.58        92          98
# 2      Talnakh      RU  69.4865   88.3972    -23.80        98         100
# 3     Khatanga      RU  71.9667  102.5000    -19.01        98         100
# 4       Castro      BR -24.7911  -50.0119     70.00        70          53
#
#    Wind Speed Current Description
# 0        4.00     overcast clouds
# 1        2.84     overcast clouds
# 2       11.23     overcast clouds
# 3       14.36          light snow
# 4        9.26       broken clouds

# %%
file_to_save = os.path.join('Weather_Database', 'Weatherpy_Database.csv')
city_data_df.to_csv(file_to_save, index_label = 'City_ID')
